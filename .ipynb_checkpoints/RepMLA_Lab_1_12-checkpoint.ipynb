# %% [markdown]
# <div>
# <img src="https://drive.google.com/uc?export=view&id=1vK33e_EqaHgBHcbRV_m38hx6IkG0blK_" width="350"/>
# </div>
#
# #**Artificial Intelligence - MSc**
# CS6501 - MACHINE LEARNING AND APPLICATIONS
# #**Business Analytics - MSc**
# ET5003 - MACHINE LEARNING APPLICATIONS
# ##***Annual Repeat***
# ###Instructor: Enrique Naredo
#
# ###RepMLA_Lab-1.12
#
# Student ID: 0427845
#
# Student name: Alison O'Connor

# %% [markdown]
# # Matplotlib exercises

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 6
# Bar plot of x and money below

# %%
#input
x = np.arange(4)
money = [1.5e5, 2.5e6, 5.5e6, 2.0e7]

plt.bar(x, height=money)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Problem 7
# Plot the graph of the function $\cos(8 x)$ in red and $x^2$ in blue for $x \in[0,1]$ and add the label "x" and "f(x)" to the respective columns using `fontsize` 14.

# %%
x=np.arange(0, 1.01, 0.01)
new=x*x

plt.plot(x, np.cos(8*x), color='red')
plt.plot(new, np.cos(8*x), color='blue')
plt.xlabel('x', fontsize=14)
plt.ylabel('f(x)', fontsize=14)
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# # Problem 8
# Plot the graph of the function $\cos(8 x)$ in red and $x^2$ in blue for $x \in[0,1]$ and add a legend
# with labels "cos(8x)" and "$x^2$"

# %%
x=np.arange(0, 1.01, 0.01)
new=x*x

plt.plot(x, np.cos(8*x), color='red', label='cos(8x)')
plt.plot(new, np.cos(8*x), color='blue', label='$x^2$')
plt.xlabel('x', fontsize=14)
plt.ylabel('f(x)', fontsize=14)
plt.legend()

# %% [markdown]
# # Problem 9
# Data=np.random.laplace(0,2,100)

# %%
Data=np.random.laplace(0,2,100)
Data
# Out:
# array([ 6.79068528e-01, -2.48004329e-01,  3.37728064e-01,  4.15431983e-01,
#        -2.84060881e+00, -1.29510503e+00,  1.31824868e+00,  3.02324312e+00,
#        -4.25369734e-01, -9.44364823e-01, -1.47200932e-01,  4.22077523e+00,
#         3.86042710e+00, -3.06657969e+00, -1.83301921e+00,  1.77662853e+00,
#        -1.12120220e+01, -3.41353586e-01,  3.73356567e-01, -6.33197260e-01,
#        -1.69926951e+00, -1.06659500e+00, -2.54977915e-01, -1.48419152e+00,
#         2.23070935e+00,  2.57583029e+00,  9.42382707e-01,  1.72218179e+00,
#        -2.14570215e+00,  9.98762627e-01, -1.30729498e-01, -1.81992888e-01,
#        -6.92713263e-01, -3.80909453e+00, -5.22485236e-01, -1.80459831e+00,
#         3.03779879e+00,  3.88234713e+00, -1.66673035e+00,  3.42495794e+00,
#        -1.25142300e-01, -1.97644562e+00, -1.71371143e+00, -8.53968826e-01,
#        -1.81914208e+00,  7.51589759e-01, -2.00091851e+00,  5.67120601e+00,
#         8.15180636e-01, -1.75117715e-01, -6.08461064e-01,  1.61002410e+00,
#        -3.00445874e-03, -5.24035252e+00, -5.53941876e+00,  2.61646066e+00,
#         4.35379527e-01,  6.61833025e-01, -1.89118689e+00,  2.00414961e+00,
#         8.91154035e+00,  2.09741408e-01,  2.74734797e+00, -2.05375572e+00,
#        -3.88008476e-01,  2.54765320e-01, -8.36749065e-01,  1.46201409e+00,
#        -2.29644016e-01,  2.24574819e-01,  5.98974290e+00, -9.87764887e-02,
#        -9.96460225e-02,  1.99574125e+00, -7.44915458e+00,  1.49095189e-01,
#         1.03642425e+00,  1.57592465e-01, -5.74066538e-01, -3.52683513e+00,
#        -8.90026338e+00, -7.16781269e-01, -2.69113462e+00, -4.29021877e-02,
#         3.26773198e+00, -2.01087372e+00, -6.35957542e-02, -1.15016901e+00,
#         1.25348905e+00, -3.64647594e+00, -5.30868994e+00, -2.84225435e-02,
#         6.66243462e-01,  4.45420330e-01, -1.28802282e+00, -1.73460155e+00,
#        -4.22719434e+00,  2.56931811e-01,  1.67993263e-01, -4.03973607e+00])

# %% [markdown]
# # Problem 10
# Plot the graph of the 2D function $e^{-x^2-y^2}$  for $x,y \in[-3,3]$.

# %%
x=np.random.uniform(-3, 3)
xsq=x*x
y=np.random.uniform(-3, 3)
ysq=y*y

import math
func=math.e^(xsq*ysq)

plt.plot(x, func)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f1d05bc28fda> in <module>
#       5
#       6 import math
# ----> 7 func=math.e^(xsq*ysq)
#       8
#       9 plt.plot(x, func)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'float'
